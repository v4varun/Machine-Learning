# %% [markdown]
# https://blamouche.medium.com/a-quick-openais-language-models-comparison-9987ddb2a723

# %%
import pandas as pd

from time import sleep
from datetime import datetime

import openai
from openai import OpenAI

import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

client = OpenAI()

# %% [markdown]
# https://platform.openai.com/docs/models/continuous-model-upgrades

# %%
models = client.models.list()

models
# Out:
# SyncPage[Model](data=[Model(id='text-search-babbage-doc-001', created=1651172509, object='model', owned_by='openai-dev'), Model(id='curie-search-query', created=1651172509, object='model', owned_by='openai-dev'), Model(id='text-davinci-003', created=1669599635, object='model', owned_by='openai-internal'), Model(id='text-search-babbage-query-001', created=1651172509, object='model', owned_by='openai-dev'), Model(id='babbage', created=1649358449, object='model', owned_by='openai'), Model(id='babbage-search-query', created=1651172509, object='model', owned_by='openai-dev'), Model(id='text-babbage-001', created=1649364043, object='model', owned_by='openai'), Model(id='text-similarity-davinci-001', created=1651172505, object='model', owned_by='openai-dev'), Model(id='davinci-similarity', created=1651172509, object='model', owned_by='openai-dev'), Model(id='code-davinci-edit-001', created=1649880484, object='model', owned_by='openai'), Model(id='curie-similarity', created=1651172510, objec
# ...

# %%
models.data
# Out:
# [Model(id='text-search-babbage-doc-001', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='curie-search-query', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='text-davinci-003', created=1669599635, object='model', owned_by='openai-internal'),
#  Model(id='text-search-babbage-query-001', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='babbage', created=1649358449, object='model', owned_by='openai'),
#  Model(id='babbage-search-query', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='text-babbage-001', created=1649364043, object='model', owned_by='openai'),
#  Model(id='text-similarity-davinci-001', created=1651172505, object='model', owned_by='openai-dev'),
#  Model(id='davinci-similarity', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='code-davinci-edit-001', created=1649880484, object='model', owned_by='openai'),
# ...

# %%
models_list = []

for model in models.data:
    model_dict = {
        "id": model.id,
        "object": model.object,
        "created": datetime.utcfromtimestamp(model.created).strftime('%Y-%m-%d %H:%M:%S'),
        "owned_by": model.owned_by,
    }
    models_list.append(model_dict)

df = pd.DataFrame(models_list)

df.sample(15)
# Out:
#                              id object              created         owned_by
# 49               ada-similarity  model  2022-04-28 19:01:47       openai-dev
# 61  gpt-3.5-turbo-instruct-0914  model  2023-09-07 21:34:32           system
# 51      text-similarity-ada-001  model  2022-04-28 19:01:45       openai-dev
# 21       text-embedding-ada-002  model  2022-12-16 19:01:39  openai-internal
# 36     babbage-code-search-text  model  2022-04-28 19:01:49       openai-dev
# 55               text-curie-001  model  2022-04-07 20:40:43           openai
# 28                  babbage-002  model  2023-08-21 16:16:55           system
# 26          ada-search-document  model  2022-04-28 19:01:47       openai-dev
# 31        curie-search-document  model  2022-04-28 19:01:48       openai-dev
# 57                        tts-1  model  2023-04-19 21:49:11  openai-internal
# 43  text-search-curie-query-001  model  2022-04-28 19:01:49       openai-dev
# ...

# %%
def generate_chat_response(model_id, user_message, max_tokens=256):
    try:
        response = client.chat.completions.create(
            model = model_id,
            messages = [
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": user_message}
            ],
            temperature = 0,
            max_tokens = max_tokens,
        )
        print(response.model)
        print(response.choices[0].message.content)
    except Exception as e:
        print(e)

# %% [markdown]
# https://platform.openai.com/docs/models/gpt-3-5
#
# GPT-3.5 models can understand and generate natural language or code. Our most capable and cost effective model in the GPT-3.5 family is gpt-3.5-turbo which has been optimized for chat using the Chat Completions API but works well for traditional completions tasks as well.
#
# If you want to use the latest model version, use the standard model names like gpt-4 or gpt-3.5-turbo.

# %%
model_id = 'gpt-3.5-turbo'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# gpt-3.5-turbo-0613
# The dog runs in the park.

# %%
model_id = 'gpt-4'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# gpt-4-0613
# The dog runs in the park.

# %% [markdown]
# We likely do not have access to this model or it does not exist

# %%
model_id = 'gpt-4-32k-0613'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# "Error code: 404 - {'error': {'message': 'The model `gpt-4-32k-0613` does not exist or you do not have access to it. Learn more: https://help.openai.com/en/articles/7102672-how-can-i-access-gpt-4.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}"

# %% [markdown]
# This model may not exist later on - I just picked the current latest model from the previous output

# %%
model_id = 'gpt-4-0613'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# gpt-4-0613
# The dog runs in the park.

# %% [markdown]
# #### Legacy models
#
# https://platform.openai.com/docs/models/gpt-3
#
# GPT-3 models can understand and generate natural language. These models were superseded by the more powerful GPT-3.5 generation models. However, the original GPT-3 base models (davinci, curie, ada, and babbage) are current the only models that are available to fine-tune.

# %%
model_id = 'text-davinci-003'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# "Error code: 404 - {'error': {'message': 'This is not a chat model and thus not supported in the v1/chat/completions endpoint. Did you mean to use v1/completions?', 'type': 'invalid_request_error', 'param': 'model', 'code': None}}"

# %%
def generate_chat_response(model_id, user_message, max_tokens=256):
    try:
        if model_id.startswith("gpt-"):
            response = client.chat.completions.create(
                model = model_id,
                messages = [
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": user_message}
                ],
                temperature = 0,
                max_tokens = max_tokens,
            )
            print(response.model)
            print(response.choices[0].message.content)
        else:
            response = client.completions.create(
                model = model_id,
                prompt = user_message,
                temperature = 0,
                max_tokens = max_tokens
            )

            print(response.model)
            print(response.choices[0].text)
    except Exception as e:
        print(e)

# %%
model_id = 'text-davinci-003'
user_message = "Translate the following Spanish text to English: 'El perro corre en el parque."

generate_chat_response(model_id, user_message)
# Out:
# text-davinci-003
#
#
# The dog runs in the park.

# %% [markdown]
# The resulting InstructGPT models are much better at following instructions than GPT-3 (GPT-3 is the older simpler model). They also make up facts less often, and show small decreases in toxic output generation. Our labelers prefer outputs from our 1.3B InstructGPT model over outputs from a 175B GPT-3 model, despite having more than 100x fewer parameters. At the same time, we show that we don’t have to compromise on GPT-3’s capabilities, as measured by our model’s performance on academic NLP evaluations.

# %%
model_ids = [
    "babbage-002",
    "text-babbage-001",
    "davinci",
    "curie-instruct-beta",
    "curie",
    "davinci-instruct-beta",
    "text-curie-001",
    "text-davinci-001",
    "text-davinci-002",
    "text-davinci-003",
    "ada",
    "text-ada-001",
    "gpt-3.5-turbo",
    "gpt-4"
]

# %% [markdown]
# ### TODO Recording:
#
# - While recording this click on the left side next to the output so you don't get a separate scroll for the output results
# - You should just have the scroll for the notebook and use that

# %%
user_message = "Write a Python function that calculates the factorial of a given integer."

separator = "=" * 80

for model_id in model_ids:
    print(separator)
    generate_chat_response(model_id, user_message)
    print(separator)
    sleep(15)
# Out:
# ...
# babbage-002
# ...

# %%
user_message = "Translate the phrase 'I love learning new languages' into Hindi."

separator = "=" * 80

for model_id in model_ids:
    print(separator)
    generate_chat_response(model_id, user_message)
    print(separator)
    sleep(15)
# Out:
# ...
# babbage-002
#  1. I love learning new languages. 2. I love learning new languages. 3. I love learning new languages. 4. I love learning new languages. 5. I love learning new languages. 6. I love learning new languages. 7. I love learning new languages. 8. I love learning new languages. 9. I love learning new languages. 10. I love learning new languages. 11. I love learning new languages. 12. I love learning new languages. 13. I love learning new languages. 14. I love learning new languages. 15. I love learning new languages. 16. I love learning new languages. 17. I love learning new languages. 18. I love learning new languages. 19. I love learning new languages. 20. I love learning new languages. 21. I love learning new languages. 22. I love learning new languages. 23. I love learning new languages. 24. I love learning new languages. 25. I love learning new languages. 26. I love learning new languages. 27. I love learning new languages. 28. I love learning new languages. 29. I
# ...

# %% [markdown]
# #### Outdated but still useful
# https://platform.openai.com/docs/model-index-for-researchers
#
# GPT-3.5 series is a series of models that was trained on a blend of text and code from before Q4 2021. The following models are in the GPT-3.5 series:
#
# - code-davinci-002 is a base model, so good for pure code-completion tasks
# - text-davinci-002 is an InstructGPT model based on code-davinci-002
# - text-davinci-003 is an improvement on text-davinci-002
# - gpt-3.5-turbo is an improvement on text-davinci-003, optimized for chat
#
# Note below that the story outputs from the gpt-3.5 precursors are pretty good

# %%
user_message = """
    Write a creative and engaging short story about a
    detective solving a mysterious murder case in a small town.
"""

separator = "=" * 80


for model_id in model_ids:
    print(separator)
    generate_chat_response(model_id, user_message)
    print(separator)
    sleep(15)
# Out:
# ...
# babbage-002
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
#     You can use any genre you like, but it must be a short story.
# ...
